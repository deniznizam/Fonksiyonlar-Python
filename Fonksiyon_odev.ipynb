# %% [markdown]
# #### Ödev 1
# Kullanıcıdan pi değeri ve yarıçap bilgisi alarak dairenin alanını hesaplayan bir fonksiyon oluşturulur.

# %%
def alan_hesabi():
        yaricap = float(input("Lütfen yarıçap bilgisi giriniz."))
        pi = float(input("Baz alınacak pi değerini giriniz."))
        x = yaricap*yaricap*pi
        print("Dairenizin alanı: ", x)
alan_hesabi()
# Out:
# Dairenizin alanı:  27.0

# %% [markdown]
# #### Ödev 2
#
# Faktöriyel adında fonksiyon oluşturulur. Döngü kullanarak parametre olarak girilen sayının faktöriyeli hesaplanır. Format metodunu kullanılarak ekrana yazdırılır.

# %%
#def faktoriyel():
  #  x = int(input("Lütfen faktöriyelini almak istediğiniz sayıyı giriniz."))
  #  xf = x 
  #  print("{} sayısının faktöriyeli {} olur".format(x,xf))

def faktoriyel():
    y = 1
    x = int(input("Hangi sayının faktöriyelini almak istiyorsunuz?"))
while x > 0:
    yx = x*y
  return(str(x) + "sayısının faktöriyeli {} sayısıdır. " , format.(str(yx))) 
faktoriyel()
# Out:
#   File <string>:11
#     return(str(x) + "sayısının faktöriyeli {} sayısıdır. " , format.(str(yx)))
#                                                                                ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# #### Ödev 3
# Kişinin fonksiyona doğum yılını vererek kaç yaşında olduğunu hesaplayan bir fonksiyon oluşturun.

# %%
def dogum():
    x= int(input("Doğum yılınızı giriniz."))
    yas = 2025-x
    print("Yaşınız: ",yas)
dogum()
# Out:
# Yaşınız:  23

# %% [markdown]
# #### Ödev 4
#
# Doğum yılı ve isim bilgisi verilen fonksiyon kişinin emekli olup olmadığını söylesin.(Kişi 65 yaşında ise emekli olur.) Burada yaş hesabını yukarıdaki örnekteki fonksiyonu kullanarak yapsın.(Yani fonksiyon içinde fonksiyon kullanmanızı istiyorum :)) Kişi 65 yaşında ya da daha fazlaysa "Emekli oldunuz" yanıtını, 65 yaşından küçükse emekliliğine kaç yıl kaldığını da hesaplayarak "(isim) emekliliğine (yıl) kaldı." yanıtını versin.

# %%
def dogum():
    i = str(input("İsminizi giriniz."))
    x= int(input("Doğum yılınızı giriniz."))
    yas = 2025-x
    if yas < 65:
        y= 65-yas
        print("Sayın ",i," Emekli olmanıza ",y," yıl kadar vakit var.") 
    else :
        print("Merhaba ",i, " Emekli oldunuz.")
dogum()
# Out:
# Merhaba  1800  Emekli oldunuz.
